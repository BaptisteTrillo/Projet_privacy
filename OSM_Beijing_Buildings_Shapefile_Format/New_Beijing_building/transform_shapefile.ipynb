# %%
import geopandas as gpd

# Lire le fichier Shapefile
gdf = gpd.read_file("../OSM_Beijing_Buildings_Shapefile_Format/gis_osm_buildings_a_free_1.shp")

# Afficher les 5 premières lignes
print(gdf.head())

# Vérifier le système de coordonnées (CRS)
print(gdf.crs)

# Vérifier le nombre de lignes
print(f"Nombre d'entités : {len(gdf)}")
# Out:
#      osm_id  code    fclass   name  type  \
# 0   4974233  1500  building  国家大剧院  None
# 1  24817887  1500  building   None  None
# 2   8854349  1500  building    中和殿  None
# 3  25097188  1500  building     端门  None
# 4  25109960  1500  building    正阳门  None
#
#                                             geometry
# 0  POLYGON ((116.38225 39.90327, 116.38225 39.903...
# 1  POLYGON ((116.47607 39.92342, 116.47607 39.923...
# 2  POLYGON ((116.39063 39.91659, 116.39078 39.916...
# 3  POLYGON ((116.39049 39.90916, 116.3905 39.9091...
# 4  POLYGON ((116.39097 39.89927, 116.39226 39.899...
# EPSG:4326
# Nombre d'entités : 123888

# %%
# Lire le fichier Shapefile
bejing_centroid = gpd.read_file("../../my-home-is-my-secret/my-home-is-my-secret-master/input/centroids-utm.shp")

# Afficher les 5 premières lignes
print(bejing_centroid.head())

# Vérifier le système de coordonnées (CRS)
print(bejing_centroid.crs)

# Vérifier le nombre de lignes
print(f"Nombre d'entités : {len(bejing_centroid)}")
# Out:
#       osm_id  code    fclass                  name        type  \
# 0  289030316  1500  building                  None        None
# 1    4217650  1500  building  Aalto Tietotekniikka  university
# 2  289030318  1500  building                  None        None
# 3    4220761  1500  building                  None        None
# 4  289030319  1500  building                  None        None
#
#                          geometry
# 0  POINT (371390.465 6678272.882)
# 1  POINT (379182.399 6674225.255)
# 2  POINT (371483.987 6678265.524)
# 3    POINT (381166.6 6676424.438)
# 4  POINT (371399.045 6678238.584)
# EPSG:32635
# Nombre d'entités : 185972
